# %% [markdown]
# # How to write an explicit loop code the goes through the entire column and scraps the text from the PDF files one by one

# %%
$ pip install at requests
# Out:
#   Input In [3]
#     $ pip install at requests
#     ^
# SyntaxError: invalid syntax

# %%
$ pip install requests
# Out:
#   Input In [4]
#     $ pip install requests
#     ^
# SyntaxError: invalid syntax

# %%
import requests

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
git clone git://github.com/psf/requests.git
# Out:
#   Input In [7]
#     git clone git://github.com/psf/requests.git
#         ^
# SyntaxError: invalid syntax

# %%
 r = requests.get('https://httpbin.org/basic-auth/user/pass', auth=('user', 'pass'))

# %%
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '{\n  "authenticated": true, \n  "user": "user"\n}\n'

# %%
r.json()
# Out:
# {'authenticated': True, 'user': 'user'}

# %%
python -m pip install requests
# Out:
#   Input In [14]
#     python -m pip install requests
#               ^
# SyntaxError: invalid syntax

# %%
requests.get(url, params={key: value}, args)
# Out:
#   Input In [15]
#     requests.get(url, params={key: value}, args)
#                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
import requests

# Making a GET request
r = requests.get('https://api.github.com/users/naveenkrnl')

# check status code for response received
# success code - 200
print(r)

# print content of request
print(r.content)
# Out:
# <Response [200]>
# ...

# %%
python request.py
# Out:
#   Input In [17]
#     python request.py
#            ^
# SyntaxError: invalid syntax

# %%
install requests
# Out:
#   Input In [1]
#     install requests
#             ^
# SyntaxError: invalid syntax

# %%
import requests

# %%
r = requests.get('http:///Users/macintosh/Desktop/THESIS?')
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 r = requests.get('/Users/macintosh/Desktop/THESIS')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 r = requests.get('http:///Users/macintosh/Desktop/THESIS?')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
# ...

# %%
r = requests.get('https://investmentpolicy.unctad.org/international-investment-agreements')

# %%
print(r)
# Out:
# <Response [200]>

# %%
print(r.content)
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html>\n<head>\r\n    <title>International Investment Agreements Navigator | UNCTAD Investment Policy Hub</title>\r\n    <meta charset="utf-8" />\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\r\n    <meta name="description" content="Discover UNCTAD\xe2\x80\x99s one stop shop on all investment policy matters ranging from national and international regulation to cutting-edge publications, news and discussions." />\r\n        <meta name="google-translate-customization" content="b339f31af11ae024-7be5a8e313bec28f-gea461c4545ed4fde-1e" />\r\n    <link rel="stylesheet" href="/Content/dist/vendor.css">\r\n    <link rel="stylesheet" href="/Content/dist/main.css">\r\n    <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Muli:300,400,600,700&amp;subset=latin-ext">\r\n    <link href="https://fonts.googleapis.com/c
# ...

# %%
response = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 response = requests.get(url)
#
# NameError: name 'url' is not defined

# %%
response = requests.get(https://investmentpolicy.unctad.org/international-investment-agreements#:~:text=Full%20text%3A-,en,-%7C%20ja)
# Out:
#   Input In [9]
#     response = requests.get(https://investmentpolicy.unctad.org/international-investment-agreements#:~:text=Full%20text%3A-,en,-%7C%20ja)
#                                  ^
# SyntaxError: invalid syntax

# %% [raw]
# # requests 2.28.1

# %%
import requests

# %%
r = requests.get ('')
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 r = requests.get ('')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
# ...

# %%
# Import libraries

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
# URL from which pdfs to be downloaded

# %%
url = "https://investmentpolicy.unctad.org/international-investment-agreements/treaty-files/5747/download"

# %%
# Requests URL and get response object

# %%
response = requests.get(url)

# %%
# Parse text obtained

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Find all hyperlinks present on webpage

# %%
links = soup.find_all('a')

# %%
i = 0

# %%
# From all links check for pdf link and
# if present download file

# %%
for link in links:
    if ('.pdf' in link.get('href', [])):
        i += 1
        print("Downloading file: ", i)

# %%
# Get response object for link

# %%
response = requests.get(links.get('href'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 response = requests.get(links.get('href'))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'get'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
# Write content in pdf file

# %%
pdf = open("pdf"+str(i)+".pdf", 'wb')
        pdf.write(response.content)
        pdf.close()
        print("File ", i, " downloaded")
  
print("All PDF files downloaded")
# Out:
#   Input In [1]
#     pdf.write(response.content)
#     ^
# IndentationError: unexpected indent

# %%
import io

# %%
url = "https://investmentpolicy.unctad.org/international-investment-agreements/treaty-files/5747/download"

# %%
url = requests.get (url)

# %%
html_content = read.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 html_content = read.content
#
# NameError: name 'read' is not defined

# %%
import requests

# %%
doc = requests.get("https://investmentpolicy.unctad.org/international-investment-agreements/treaty-files/6443/download")

# %%
doc
# Out:
# <Response [200]>

# %%
with open("mypdf.pdf", 'wb') fw:
    fw.write(response.content)
         
print("All PDF files downloaded")
# Out:
#   Input In [5]
#     with open("mypdf.pdf", 'wb') fw:
#                                  ^
# SyntaxError: invalid syntax

# %%
with open("mypdf.pdf", 'wb') as fw:
    fw.write(response.content)
         
print("All PDF files downloaded")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       1 with open("mypdf.pdf", 'wb') as fw:
# ----> 2     fw.write(response.content)
#       4 print("All PDF files downloaded")
#
# NameError: name 'response' is not defined

# %%
with open("mypdf.pdf", 'wb') as fw:
    fw.write(doc.content)
         
print("All PDF files downloaded")
# Out:
# All PDF files downloaded

# %%
import pandas as pd

# %%
tables = pd.read_html ("rawtables.html")

# %%
len ( tables)
# Out:
# 1

# %%
tables [0]
# Out:
#     No.                                        Short title  \
# 0     1                      Kazakhstan - Qatar BIT (2022)
# 1     2       Indonesia - United Arab Emirates CEPA (2022)
# 2     3                         Bahrain - Japan BIT (2022)
# 3     4      Philippines - United Arab Emirates BIT (2022)
# 4     5                    Israel - Philippines BIT (2022)
# 5     6                 Indonesia - Switzerland BIT (2022)
# 6     7                       Türkiye - Uruguay BIT (2022)
# 7     8            New Zealand - United Kingdom FTA (2022)
# 8     9           India - United Arab Emirates CEPA (2022)
# 9    10       Mozambique - United Arab Emirates BIT (2022)
# 10   11                          Hungary - Oman BIT (2022)
# 11   12            Pacific Alliance - Singapore FTA (2022)
# 12   13              Australia - United Kingdom FTA (2021)
# 13   14                        Chile - Paraguay FTA (2021)
# 14   15            Cambodia - Republic of Korea FTA (2021)
# ...

# %%
meta_tables = pd.read_html("https://investmentpolicy.unctad.org/international-investment-agreements/treaty-files/6443/download", extract_links="all")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 meta_tables = pd.read_html("https://investmentpolicy.unctad.org/international-investment-agreements/treaty-files/6443/download", extract_links="all")
#
# NameError: name 'pd' is not defined

# %%
pip install -U [Pandas 1.5.0]
# Out:
# ERROR: Invalid requirement: '[Pandas'
# Note: you may need to restart the kernel to use updated packages.

# %%
sys.version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 sys.version
#
# NameError: name 'sys' is not defined

# %%
python_version()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 python_version()
#
# NameError: name 'python_version' is not defined

# %%
import pandas as pd

# %%
import pandas 1.5.0 as pd
# Out:
#   Input In [5]
#     import pandas 1.5.0 as pd
#                   ^
# SyntaxError: invalid syntax

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
pip install pandas=version 1.5.0
# Out:
# ERROR: Invalid requirement: 'pandas=version'
# Hint: = is not a valid operator. Did you mean == ?
# Note: you may need to restart the kernel to use updated packages.

# %%
pandas 1.5.0
# Out:
#   Input In [9]
#     pandas 1.5.0
#            ^
# SyntaxError: invalid syntax

# %%
 ! pip install -U pandas

# %%
conda update pandas

# %%
conda install pandas=1.5.0

# %%
import requests

# %%
doc = requests.get("https://investmentpolicy.unctad.org/international-investment-agreements")

# %%
doc
# Out:
# <Response [200]>

# %%
with open("mypdf.pdf", 'wb') as fw:
    fw.write(doc.content)
         
print("All PDF files downloaded")
# Out:
# All PDF files downloaded

# %%
import pandas as pd

# %%
tables = pd.read_html ("try_it.html", extract_links="all")

# %%
len (tables)
# Out:
# 1

# %%
tables [0]
# Out:
#     No.                                         Full title  \
# 0     1                                                NaN
# 1     2  Comprehensive Economic Partnership Agreement (...
# 2     3                                                NaN
# 3     4                                                NaN
# 4     5                                                NaN
# 5     6                                                NaN
# 6     7                                                NaN
# 7     8  Free Trade Agreement between the United Kingdo...
# 8     9  Comprehensive Economic Partnership Agreement (...
# 9    10                                                NaN
# 10   11                                                NaN
# 11   12                                                NaN
# 12   13                                                NaN
# 13   14                                                NaN
# 14   15                                                NaN
# ...

# %%
tables = pd.read_html ("try_it.html", extract_links="all")

# %%
len (tables)
# Out:
# 1

# %%
tables [0]
# Out:
#    (No., None)                                    (Full title, #)  \
# 0    (1, None)  (, /international-investment-agreements/treati...
# 1    (2, None)  (Comprehensive Economic Partnership Agreement ...
# 2    (3, None)  (, /international-investment-agreements/treati...
# 3    (4, None)  (, /international-investment-agreements/treati...
# 4    (5, None)  (, /international-investment-agreements/treati...
# 5    (6, None)  (, /international-investment-agreements/treati...
# 6    (7, None)  (, /international-investment-agreements/treati...
# 7    (8, None)  (Free Trade Agreement between the United Kingd...
# 8    (9, None)  (Comprehensive Economic Partnership Agreement ...
# 9   (10, None)  (, /international-investment-agreements/treati...
# 10  (11, None)  (, /international-investment-agreements/treati...
# 11  (12, None)  (, /international-investment-agreements/treati...
# 12  (13, None)  (, /international-investment-agreements/treati...
# ...

# %%
tables = pd.read_html ("https://investmentpolicy.unctad.org/international-investment-agreements", extract_links="all")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 tables = pd.read_html ("https://investmentpolicy.unctad.org/international-investment-agreements", extract_links="all")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# ...

# %%
tables = pd.read_html ("try_it.html", extract_links="all")

# %%
print (tables)
# Out:
# [   (No., None)                                    (Full title, #)  \
# 0    (1, None)  (, /international-investment-agreements/treati...
# 1    (2, None)  (Comprehensive Economic Partnership Agreement ...
# 2    (3, None)  (, /international-investment-agreements/treati...
# 3    (4, None)  (, /international-investment-agreements/treati...
# 4    (5, None)  (, /international-investment-agreements/treati...
# 5    (6, None)  (, /international-investment-agreements/treati...
# 6    (7, None)  (, /international-investment-agreements/treati...
# 7    (8, None)  (Free Trade Agreement between the United Kingd...
# 8    (9, None)  (Comprehensive Economic Partnership Agreement ...
# 9   (10, None)  (, /international-investment-agreements/treati...
# 10  (11, None)  (, /international-investment-agreements/treati...
# 11  (12, None)  (, /international-investment-agreements/treati...
# 12  (13, None)  (, /international-investment-agreements/treati...
# ...

# %%
df.head (10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df.head (10)
#
# NameError: name 'df' is not defined

# %%
df=pd.read_html("try_it.html")

# %%
df
# Out:
# [    No.                                         Full title  \
#  0     1                                                NaN
#  1     2  Comprehensive Economic Partnership Agreement (...
#  2     3                                                NaN
#  3     4                                                NaN
#  4     5                                                NaN
#  5     6                                                NaN
#  6     7                                                NaN
#  7     8  Free Trade Agreement between the United Kingdo...
#  8     9  Comprehensive Economic Partnership Agreement (...
#  9    10                                                NaN
#  10   11                                                NaN
#  11   12                                                NaN
#  12   13                                                NaN
#  13   14                                                NaN
#  14   15                                                NaN
# ...

# %%
df.head (10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 df.head (10)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
df["Text"].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df["Text"].head()
#
# TypeError: list indices must be integers or slices, not str

# %%
from urllib import request

# %%
from urllib.request import Request, urlopen

# %%
url = "https://investmentpolicy.unctad.org/international-investment-agreements"

# %%
request_site = Request(url)

# %%
webpage = urlopen(request_site).read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 webpage = urlopen(request_site).read()
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
# ...

# %%
print(webpage[])
# Out:
#   Input In [28]
#     print(webpage[])
#                   ^
# SyntaxError: invalid syntax

# %%
import requests

# %%
doc = requests.get("https://investmentpolicy.unctad.org/international-investment-agreements")

# %%
doc
# Out:
# <Response [200]>

# %%
with open("mypdf.pdf", 'wb') as fw:
    fw.write(doc.content)
         
print("All PDF files downloaded")
# Out:
# All PDF files downloaded

# %%
import pandas as pd

# %%
tables = pd.read_html ("try_it.html")

# %%
len ( tables)
# Out:
# 1

# %%
tables [0]
# Out:
#     No.                                         Full title  \
# 0     1                                                NaN
# 1     2  Comprehensive Economic Partnership Agreement (...
# 2     3                                                NaN
# 3     4                                                NaN
# 4     5                                                NaN
# 5     6                                                NaN
# 6     7                                                NaN
# 7     8  Free Trade Agreement between the United Kingdo...
# 8     9  Comprehensive Economic Partnership Agreement (...
# 9    10                                                NaN
# 10   11                                                NaN
# 11   12                                                NaN
# 12   13                                                NaN
# 13   14                                                NaN
# 14   15                                                NaN
# ...

# %%
tables = pd.read_html("try_it.html", extract_links="all")

# %%
tables [0]
# Out:
#    (No., None)                                    (Full title, #)  \
# 0    (1, None)  (, /international-investment-agreements/treati...
# 1    (2, None)  (Comprehensive Economic Partnership Agreement ...
# 2    (3, None)  (, /international-investment-agreements/treati...
# 3    (4, None)  (, /international-investment-agreements/treati...
# 4    (5, None)  (, /international-investment-agreements/treati...
# 5    (6, None)  (, /international-investment-agreements/treati...
# 6    (7, None)  (, /international-investment-agreements/treati...
# 7    (8, None)  (Free Trade Agreement between the United Kingd...
# 8    (9, None)  (Comprehensive Economic Partnership Agreement ...
# 9   (10, None)  (, /international-investment-agreements/treati...
# 10  (11, None)  (, /international-investment-agreements/treati...
# 11  (12, None)  (, /international-investment-agreements/treati...
# 12  (13, None)  (, /international-investment-agreements/treati...
# ...

# %%
pd.__version__
# Out:
# '1.5.0'

# %%
import pandas as pd

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
response = requests.get (https://investmentpolicy.unctad.org/international-investment-agreements)
# Out:
#   Input In [4]
#     response = requests.get (https://investmentpolicy.unctad.org/international-investment-agreements)
#                                   ^
# SyntaxError: invalid syntax

# %%
url= 'try_it.html'

# %%
response = requests.get(https://investmentpolicy.unctad.org/international-investment-agreements)
# Out:
#   Input In [10]
#     response = requests.get(https://investmentpolicy.unctad.org/international-investment-agreements)
#                                  ^
# SyntaxError: invalid syntax

# %%
df = pd.read_html(url)[0]

# %%
m pip install
# Out:
#   Input In [13]
#     m pip install
#       ^
# SyntaxError: invalid syntax

# %%
python pip install -m pip install --upgrade --pre pandas==1.5.0rc0
# Out:
#   Input In [14]
#     python -m pip install --upgrade --pre pandas==1.5.0rc0
#               ^
# SyntaxError: invalid syntax

# %%
pip install
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+ssh://git@github.com/pandas-dev/pandas.git@v1.5.0rc0
# Out:
# ...
#   Cloning ssh://****@github.com/pandas-dev/pandas.git (to revision v1.5.0rc0) to /private/var/folders/90/r89jt0m10hs852cgj8njrn500000gn/T/pip-req-build-xx9r0tex
#   Running command git clone -q 'ssh://****@github.com/pandas-dev/pandas.git' /private/var/folders/90/r89jt0m10hs852cgj8njrn500000gn/T/pip-req-build-xx9r0tex
# The authenticity of host 'github.com (140.82.121.3)' can't be established.
# ECDSA key fingerprint is SHA256:Jqj8DrFWKzHPpYz4BDCUxAI5ikaEFLPL+wSLWdGOFJY.
# Are you sure you want to continue connecting (yes/no/[fingerprint])?

# %%
pd.__version__

# %%
pd.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pd.__version__
#
# NameError: name 'pd' is not defined

# %%
conda install pandas

# %%
python3 -m pip install --upgrade pandas

# %%
python -m pip install --upgrade --pre pandas==1.5.0rc0
# Out:
#   Input In [4]
#     python -m pip install --upgrade --pre pandas==1.5.0rc0
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.0'

# %%
python -m pip install --upgrade --pre pandas==1.5.0rc0
# Out:
#   Input In [5]
#     python -m pip install --upgrade --pre pandas==1.5.0rc0
#               ^
# SyntaxError: invalid syntax

# %%
conda install pandas
# Out:
# ...
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::holoviews==1.14.8=pyhd3eb1b0_0
#   - defaults/noarch::dask==2022.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda==2022.05=py39_0
#   - defaults/noarch::datashader==0.13.0=pyhd3eb1b0_1
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/osx-64::statsmodels==0.13.2=py39hca72f7f_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/noarch::hvplot==0.7.3=pyhd3eb1b0_1
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/noarch::xarray==0.20.1=pyhd3eb1b0_1
# done
#
# ## Package Plan ##
#
#   environment location: /Users/macintosh/opt/anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
# ...

# %%
conda-forge/label/pandas_rc pandas==1.5.0rc0
# Out:
# usage: conda [-h] [-V] command ...
# conda: error: argument command: invalid choice: 'pandas==1.5.0rc0' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'package', 'remove', 'rename', 'run', 'search', 'uninstall', 'update', 'upgrade', 'notices')
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
conda._version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 conda._version__
#
# NameError: name 'conda' is not defined

# %%
import requests

# %%
doc = requests.get("https://investmentpolicy.unctad.org/international-investment-agreements")

# %%
doc
# Out:
# <Response [200]>

# %%
with open("thispdf.pdf", 'wb') as fw:
    fw.write(doc.content)
         
print("All PDF files downloaded")
# Out:
# All PDF files downloaded

# %%
import pandas as pd

# %%
tables = pd.read_html ("try_it.html")

# %%
len (tables)
# Out:
# 1

# %%
tables [0]
# Out:
#     No.                                         Full title  \
# 0     1                                                NaN
# 1     2  Comprehensive Economic Partnership Agreement (...
# 2     3                                                NaN
# 3     4                                                NaN
# 4     5                                                NaN
# 5     6                                                NaN
# 6     7                                                NaN
# 7     8  Free Trade Agreement between the United Kingdo...
# 8     9  Comprehensive Economic Partnership Agreement (...
# 9    10                                                NaN
# 10   11                                                NaN
# 11   12                                                NaN
# 12   13                                                NaN
# 13   14                                                NaN
# 14   15                                                NaN
# ...

# %%
tables = pd.read_html("try_it.html", extract_links="all")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 tables = pd.read_html("try_it.html", extract_links="all")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_html() got an unexpected keyword argument 'extract_links'

# %%
conda upgrade pandas
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/macintosh/opt/anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-client-1.11.0     |   py39hecd8cb5_0         149 KB
#     anaconda-project-0.11.1    |   py39hecd8cb5_0         489 KB
#     applaunchservices-0.3.0    |   py39hecd8cb5_0          11 KB
#     arrow-1.2.3                |   py39hecd8cb5_0         146 KB
#     astroid-2.11.7             |   py39hecd8cb5_0         346 KB
#     astropy-5.1                |   py39h67323c0_0         6.7 MB
#     async-timeout-4.0.2        |   py39hecd8cb5_0          13 KB
#     autopep8-1.6.0             |     pyhd3eb1b0_1          43 KB
#     bcrypt-3.2.0               |   py39hca72f7f_1          39 KB
#     bitarray-2.5.1             |   py39hca72f7f_0         152 KB
# ...

# %%
pd.__version__

# %%
import pandas as pd

# %%
 ! pip install -U pandas

# %%
conda install pandas=1.5.0

# %%
pd.__version__
# Out:
# '1.5.1'

# %%
import requests

# %%
doc = requests.get("https://investmentpolicy.unctad.org/international-investment-agreements")

# %%
doc
# Out:
# <Response [200]>

# %%
with open("mypdf.pdf", 'wb') as fw:
    fw.write(doc.content)
         
print("All PDF files downloaded")
# Out:
# All PDF files downloaded

# %%
import pandas as pd

# %%
tables = pd.read_html ("try_it.html")

# %%
tables = pd.read_html("try_it.html", extract_links="all")

# %%
len (tables)
# Out:
# 1

# %%
tables [0]
# Out:
#    (No., None)                                    (Full title, #)  \
# 0    (1, None)  (, /international-investment-agreements/treati...
# 1    (2, None)  (Comprehensive Economic Partnership Agreement ...
# 2    (3, None)  (, /international-investment-agreements/treati...
# 3    (4, None)  (, /international-investment-agreements/treati...
# 4    (5, None)  (, /international-investment-agreements/treati...
# 5    (6, None)  (, /international-investment-agreements/treati...
# 6    (7, None)  (, /international-investment-agreements/treati...
# 7    (8, None)  (Free Trade Agreement between the United Kingd...
# 8    (9, None)  (Comprehensive Economic Partnership Agreement ...
# 9   (10, None)  (, /international-investment-agreements/treati...
# 10  (11, None)  (, /international-investment-agreements/treati...
# 11  (12, None)  (, /international-investment-agreements/treati...
# 12  (13, None)  (, /international-investment-agreements/treati...
# ...
